# %% [markdown]
# <a href="https://colab.research.google.com/github/Francoisnollet/GMC/blob/main/GMC_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello world")
x = 5
if x < 10:
    print("x est plus petit que 10")
# Out:
# Hello world
# x est plus petit que 10
